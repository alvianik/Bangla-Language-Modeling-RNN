# %%
text = """বাংলাদেশ দক্ষিণ এশিয়ার একটি জনবহুল ও উন্নয়নশীল রাষ্ট্র। ১৯৭১ সালের স্বাধীনতা যুদ্ধে পাকিস্তান থেকে স্বাধীনতা অর্জনের পর দেশটি বিশ্ব মানচিত্রে একটি স্বাধীন রাষ্ট্র হিসেবে আবির্ভূত হয়। ভারতীয় উপমহাদেশের পূর্ব অংশে প্রাচীন ও ঐতিহাসিক অঞ্চলের প্রধান অংশের সাথে দেশটির সীমানা মিলেছে, যেখানে চার হাজারেরও বেশী বছর ধরে সভ্যতা চলছে, ক্যালকোলিথিক যুগেও। এই অঞ্চলের ইতিহাস বাংলার ইতিহাস এবং ভারতের ইতিহাসের সাথে ঘনিষ্ঠভাবে জড়িত। এলাকাটির প্রারম্ভিক ইতিহাস হল ভারতীয় সাম্রাজ্যের উত্তরাধিকার, অভ্যন্তরীণ দ্বন্দ্ব এবং হিন্দু ও বৌদ্ধের মধ্যকার দ্বন্দ্বের ইতিহাস। ত্রয়োদশ শতাব্দীর পরে যখন মুসলিম অভিযাত্রীরা, যেমন তুর্কী, ইরানীয়, মুঘল প্রভৃতি এদেশে এসেছিল তখন ইসলাম ধীরে ধীরে প্রভাবশালী হয়ে উঠেছিল। পরবর্তীতে মুসলিম শাসকরা মসজিদ এবং মাদ্রাসা নির্মাণের মাধ্যমে রূপান্তরের প্রক্রিয়াটিকে শক্তিশালী করে। বাংলা বা বাংগালা শব্দটির সঠিক উৎপত্তিটি অজানা রয়েছে। খুব সম্ভবত ১০০০ খ্রিস্টপূর্বাব্দের কাছাকাছি এ অঞ্চলে বসবাসকারী দ্রাবিড় গোষ্ঠী বঙ থেকে বঙ্গ শব্দটির উদ্ভব হয়েছে। অন্যান্য তথ্যসূত্র থেকে ধারণা করা হয় যে অষ্ট্রিক জাতির সূর্যদেবতা "বোঙ্গা" থেকে বঙ্গ কথাটির উদ্ভব হয়েছে। মহাভারত, পুরাণ ও হরিবংশের মতে রাজা বালীর বঙ্গ নামে এক দত্তক পুত্র ছিলেন যিনি বঙ্গ রাজ্য প্রতিষ্ঠা করেছিলেন। মুসলিম তথ্যসূত্রগুলো থেকে জানা যায়, হযরত নূহ (আঃ) এর দৌহিত্র হিন্দ এর পুত্র বঙ প্রথমবারের মত এই অঞ্চলে উপনিবেশ স্থাপন করেন। রাষ্ট্রকূট রাজা তৃতীয় গোবিন্দের নেসারী শিলালিপিতে প্রথম বঙ্গলা শব্দটির উল্লেখ রয়েছে যেখানে ধর্মপালকে বঙ্গলার রাজা বলে উল্লেখ করা হয়েছে। সুলতান ইলইয়াস শাহ "শাহ-ই-বাঙ্গালাহ" নামক উপাধি গ্রহণ করেন এবং তারপর থেকে সকল মুসলিম সূত্রেই বাংলাকে বাঙ্গালাহ বলা হয়েছে। বাংলাদেশে সংগঠিত প্রত্নতাত্ত্বিক খননকাজগুলি ভারতীয় উপমহাদেশের যুগের (৭০০-২০০ খ্রিস্টপূর্বাব্দ) নিদর্শ
বঙ্গ দেশ থেকে অাগত বিজয় সিংহ নামে এক ব্যক্তি স্থানীয় দ্রাবিড় রাজাদের পতন ঘটিয়ে সিংহল (সিংহ বংশীয়) নামে একটি নতুন রাজ্যের পত্তন করেন। বিজয় সিংহকে সিংহলী জাতির পিতা হিসেবে পরিগণিত করা হয়। বিজয় সিংহকে নিয়ে শ্রীলঙ্কায় একটি মহাকাব্যও রয়েছে যা "মহাবংশ" নামে পরিচিত। নন্দ সাম্রাজ্য ছিল বাংলার ইতিহাসে এক অবিস্মরণীয় যুগ। এই যুগে বাংলার শক্তিমত্তা ও প্রাচুর্য শীর্ষে অারোহন করে। এই যুগে বাংলা সমগ্র উত্তর ভারত জুড়ে সাম্রাজ্য বিস্তার করতে সক্ষম হয়। নন্দ রাজাদের জন্ম হয়েছিল বাংলায়। তারা বাংলা থেকে মগধ (বিহার) দখল করে এবং উভয় রাজ্যকে ঐক্যবদ্ধ করে বঙ্গ-মগধ নামে একটি নতুন সাম্রাজ্যের পত্তন করে। প্রাচীণ গ্রীক ইতিহাসে বাংলাকে গঙ্গারিডাই এবং মগধকে প্রাসি হিসেবে উল্লেখ করা হয়েছে। গ্রীক ইতিহাসে এই সংযুক্ত রাজ্যকে গঙ্গারিডাই ও প্রাসি বলে উল্লেখ করা হয়েছে। নন্দ রাজাগণ ছিলেন জৈন ধর্মের অনুসারী। এবং তারা ছিলেন জৈন ধর্মের আজীবিক শাখার অনুসারী। মহাপদ্ম নন্দ ছিলেন নন্দ বংশের সর্বশ্রেষ্ঠ সম্রাট। তিনি সমগ্র ভারতবর্ষ ব্যাপী ব্যাপক সামরিক অভিযান পরিচালনা করেন। তিনি কোশল (উত্তর প্রদেশ), কুরু (পূর্ব পাঞ্জাব), মৎস্য (রাজপুতানা), চেদী (মধ্য প্রদেশ ও বিহারের মধ্যস্থিত জঙ্গলাকীর্ণ অঞ্চল),অবন্তী (মধ্য প্রদেশ) প্রভৃতি অঞ্চল জয় করেন। দিগ্বিজয়ার্থে মহাপদ্ম এক বিশাল সৈন্যবাহিনী প্রস্তুত করেন। তৎকালীন ইতিহাস অনুসারে মহাপদ্মের অধীনে ২,০০,০০০ পদাতিক, ২০,০০০ অশ্বারোহী, ৪,০০০ যুদ্ধরথ ও ২,০০০ হস্তীবাহিনী ছিল। মতান্তরে তার নিকট ২,০০,০০০ পদাতিক, ৮০,০০০ অশ্বারোহী, ৮,০০০ যুদ্ধরথ ও ৬,০০০ হস্তীবাহিনী ছিল। "কথাসরিৎ সাগর" থেকে জানা যায় তিনি দক্ষিণ ভারতেরও বিরাট অংশ জয় করেছিলেন। তিনি দক্ষিণ ভারতের কলিঙ্গ ও অশ্মক এ রাজ্য দুটো জয় করেছিলেন। অশ্মক হচ্ছে মহারাষ্ট্রের পূর্ব অংশে একটি প্রাচীণ রাজ্যের নাম। এটি দক্ষিণ ভারতে অার্যদের একটি বিখ্যাত উপনিবেশ ছিল। কলিঙ্গ হচ্ছে উড়িষ্যার প্রাচীণ নাম। কলিঙ্গের হস্তিগুম্ফা শিলালিপি থেকে জানা যায় মহাপদ্ম কলিঙ্গে জল সেচের জন্য একটি বিরাট জল প্রণালী নির্মাণ করেছিলেন। তিনি কলিঙ্গ থেকে একটি জৈন তীর্থঙ্করের মূর্তিও রাজধানীতে নিয়ে যান। মহাপদ্ম ভারতবর্ষের ইতিহাসে প্রথমবারের মত একটি বৃহৎ সাম্রাজ্য স্থাপন করতে সক্ষম হন। সমগ্র ভারতবর্ষ জয় করে তিনি একরাট উপাধি গ্রহণ করেন। পরে তাকে অনুসরণ করে পশ্চিম ভারতের রাজারা বিরাট ও দক্ষিণ ভারতের রাজারা সম্রাট উপাধি গ্রহণ করে। মহাপদ্ম নন্দের পর ক্ষমতায় অাসীন হন তার পুত্র উগ্রনন্দ। উগ্রনন্দের সময় রাজ্যে ব্যাপক অর্থনৈতিক সমৃদ্ধি দেখা দেয়। তিনি ব্যক্তিগত ভাবে ৯৯০ মিলিয়ন স্বর্ণখণ্ডের অধিকারী ছিলেন। উগ্রনন্দের সময়ে পাটালিপুত্রে পাঁচটি ধর্মস্তূপ নির্মিত হয়েছিল। প্রাচীণ ভারতের বিভিন্ন ইতিহাসে উগ্রনন্দকে অর্থপিপাসু হিসেবে উল্লেখ করা হয়েছে এবং তাকে ধননন্দ নামে অভিহিত করা হয়েছে। তবে মনে রাখতে হবে উগ্রনন্দ এবং তার পিতা মহাপদ্ম বিপুল পরিমাণ রাজ্য দখল করেছিলেন এবং তারা উক্ত রাজ্যের পরাজিত রাজন্যবর্গের ওপর কর অারোপ করেছিলেন। কাজেই এইসব অভিযোগ উক্ত পরাজিত রাজন্যবর্গের বিষোদ্গার হতে পারে। উগ্রনন্দের সময় গ্রীক সম্রাট অালেকজাণ্ডার ভারতবর্ষ অাক্রমণ করেন। কিন্তু উগ্রনন্দ একটি বিরাট সেনাবাহিনী নিয়ে অালেকজাণ্ডারের মোকাবিলার জন্য প্রস্তুত হন। প্লুটার্ক বলেছেন, পোরাসের সাথে যুদ্ধের পর মেসিডোনিয়ার সৈন্যরা হতাশাগ্রস্ত হয়ে পড়ে, এবং ভারতবর্ষের অভ্যন্তরে অারও প্রবেশের জন্য অনিচ্ছুক হয়ে পড়ে। তারা জানতে পারে গঙ্গা নদী যা ২৩০ স্টেডিয়া বিস্তৃত ছিল এবং ১০০০ ফুট গভীর ছিল, তার পাশের সমস্ত তীর সমস্ত তীর সশস্ত্র যোদ্ধা, ঘোড়া এবং হাতি দ্বারা সম্পূর্ণভাবে আবৃত ছিল। গঙ্গারিডাই ও প্রাসি এর রাজা তার (আলেকজান্ডার) জন্য ২,০০,০০০ পদাতিক, ৮০,০০০ অশ্বারোহী বাহিনী, ৮,০০০ যুদ্ধরথ ও ৬,০০০ হস্তিবাহিনী নিয়ে অপেক্ষা করছিলেন। ষষ্ঠ শ
যা পার্বত্য অঞ্চল বিজয় করে তিনি মালব ও গুজরাট দখল করেন। কিন্তু এ অঞ্চলগুলো পরবর্তীতে তিনি মিহির ভোজ| মিহির ভোজের কাছে হারিয়ে ফেলেন। দেবপালের দাক্ষিণাত্য অভিযান সফল হয়েছিল। তার নির্দেশে ভ্রাতা জয়পাল রাষ্ট্রকূট রাজা অমোঘবর্ষকে পরাজিত করে উড়িষ্যা পুনর্দখল করেন। এরপর উড়িষ্যা চিরস্থায়ীভাবে পাল সাম্রাজ্যের শাসনাধীনে ছিল। পাল সম্রাটগণ বহু বৌদ্ধবিহার ও ধর্মীয় পীঠস্থান নির্মাণ করেছিলেন। বিক্রমশীল, ওদন্তপুরী ও জগদ্দল প্রভৃতি বৃহদায়তন মহাবিহার পাল স্থাপত্যের উল্লেখযোগ্য নিদর্শন। পাল সম্রাটগণ প্রথমত "মহাযান" বৌদ্ধ ধর্মের অনুসারী ছিলেন। পরবর্তীতে পালগণ হিন্দুদের বৌদ্ধধর্মে অাকৃষ্ট করার জন্য তান্ত্রিক বৌদ্ধ ধর্মের প্রবর্তন করেন। বহু হিন্দু দেবদেবীকে এই ধর্মে স্থান দেওয়া হয়। পাল সম্রাটগণ সংস্কৃত বা পালি ভাষার পরিবর্তে বাংলা ভাষাকে রাষ্ট্রভাষা হিসেবে ঘোষণা করেন। পাল রাজাদের সময়ই বাংলা সাহিত্যের প্রাচীণতম নিদর্শন চর্যাপদসমূহ রচিত হয়। তাই পাল রাজবংশকে অনেক সময় বাংলা সাহিত্যের জনক মনে করা হয়।"""
text = text.replace("|","।")

# %%
symbol_List = ["!", "@", "#", "$", "%", "^", "&", "*", "(", ")", "-", "_", "+", "=", ":", ";", "'", "\"", "{", "}", "[", "]", "\\", "<", ">", "/", ",", ".", "?", "০", "১", "২", "৩", "৪", "৫", "৬", "৭", "৮", "৯"]
for symbol in symbol_List:
    text = text.replace(symbol, "")
# mod1_text = text.replace("!","")

# sentences = []
# sentences = mod1_text.split("।")
# print(sentences)
sent = text.split("।")[:-1]
sentences = []
for sentence in sent:
    sentences.append(sentence.strip())
print(sentences)
# mod2_text = mod1_text.replace("।","")
text = text.replace("।","")
word_container = []
word = text.split(" ")
for w in word:
    if w:
        word_container.append(w)
print(word_container)
# Out:
# ['বাংলাদেশ দক্ষিণ এশিয়ার একটি জনবহুল ও উন্নয়নশীল রাষ্ট্র', 'সালের স্বাধীনতা যুদ্ধে পাকিস্তান থেকে স্বাধীনতা অর্জনের পর দেশটি বিশ্ব মানচিত্রে একটি স্বাধীন রাষ্ট্র হিসেবে আবির্ভূত হয়', 'ভারতীয় উপমহাদেশের পূর্ব অংশে প্রাচীন ও ঐতিহাসিক অঞ্চলের প্রধান অংশের সাথে দেশটির সীমানা মিলেছে যেখানে চার হাজারেরও বেশী বছর ধরে সভ্যতা চলছে ক্যালকোলিথিক যুগেও', 'এই অঞ্চলের ইতিহাস বাংলার ইতিহাস এবং ভারতের ইতিহাসের সাথে ঘনিষ্ঠভাবে জড়িত', 'এলাকাটির প্রারম্ভিক ইতিহাস হল ভারতীয় সাম্রাজ্যের উত্তরাধিকার অভ্যন্তরীণ দ্বন্দ্ব এবং হিন্দু ও বৌদ্ধের মধ্যকার দ্বন্দ্বের ইতিহাস', 'ত্রয়োদশ শতাব্দীর পরে যখন মুসলিম অভিযাত্রীরা যেমন তুর্কী ইরানীয় মুঘল প্রভৃতি এদেশে এসেছিল তখন ইসলাম ধীরে ধীরে প্রভাবশালী হয়ে উঠেছিল', 'পরবর্তীতে মুসলিম শাসকরা মসজিদ এবং মাদ্রাসা নির্মাণের মাধ্যমে রূপান্তরের প্রক্রিয়াটিকে শক্তিশালী করে', 'বাংলা বা বাংগালা শব্দটির সঠিক উৎপত্তিটি অজানা রয়েছে', 'খুব সম্ভবত  খ্রিস্টপূর্বাব্দের কাছাকাছি এ অঞ্চলে বসবাসকারী দ্রাবিড় গোষ্ঠী বঙ থেকে বঙ্গ শব্দটির উদ্ভব হয়েছে', 'অন্যান্য তথ্যসূত্র থেকে ধারণা 
# ...

# %%
unique_word = set(word_container)
print(unique_word)

int2word = dict(enumerate(unique_word))


word2int = {w: ind for ind, w in int2word.items()}
word2int["<word>"] = len(word2int)
print(word2int)

int2word[len(int2word)] = "<word>" 
print(int2word)
# Out:
# {'শাসনের', 'সমৃদ্ধ', 'উত্তরাধিকার', 'প্রাচীণ', 'অবিস্মরণীয়', 'শৈলোদ্ভব', 'হস্তিগুম্ফা', 'বঙ্গলার', 'অজানা', 'অনেক', 'করা', 'একটি', 'চলছে', 'তৃতীয়', 'ছিল', 'দৌহিত্র', 'ভারতের', 'শাহইবাঙ্গালাহ', 'রাজাগণ', 'বঙ্গমগধ', 'প্রচণ্ড', 'বনলাং', 'ঐক্যবদ্ধ', 'সম্রাটগণ', 'প্রাচীন', 'মালব', 'রামভদ্রকে', 'যখন', 'সূত্রেই', 'শশাঙ্ক', 'পাশের', 'মনে', 'প্রদেশ', 'ওপর', 'অভিযাত্রীরা', 'হয়', 'খ্রিস্টপূর্ব', 'মতে', 'অভিযোগ', 'বাংলায়', 'ইরানীয়', 'দাক্ষিণাত্য', 'নিহত', 'গোপালের', 'সর্বশ্রেষ্ঠ', 'বোঙ্গা', 'উপনিবেশ', 'অংশ', 'হয়েছে', 'সম্পূর্ণভাবে', 'সমৃদ্ধি', 'তুলতেন', 'জানা', 'বৎসরাজ', 'তাকে', 'সাম্রাজ্য', 'ভারতব্যাপী', 'রাজ্যবর্ধন', 'উদ্ভব', 'রাজপুতানার', 'অশ্মক', 'অধিকারী', 'সমগ্র', 'কুরুক্স', 'শাহ', 'এসেছিল', 'বৌদ্ধধর্মের', 'দ্রাবিড়', 'মধ্য', 'গিয়ে', 'ও', 'শাখার', 'সে', 'কনৌজ', 'অশ্বারোহী', 'মোকাবিলার', 'হারিয়ে', 'ইতিহাস', 'রাষ্ট্রভাষা', 'ভারত', 'কথা', 'অব্যাহত', 'দেবগুপ্ত', 'করে', 'অর্থনৈতিক', 'ঘোষণা', 'দখলের', 'বংশীয়', 'বিদ্যমান', 'দুই', 'ফেলেন', 'হর্ষবর্ধন', 'রক্ষা', 'রাজন্যবর্গের', 'সেনাবাহিনী
# ...

# %%
int2word
# Out:
# {0: 'শাসনের',
#  1: 'সমৃদ্ধ',
#  2: 'উত্তরাধিকার',
#  3: 'প্রাচীণ',
#  4: 'অবিস্মরণীয়',
#  5: 'শৈলোদ্ভব',
#  6: 'হস্তিগুম্ফা',
#  7: 'বঙ্গলার',
#  8: 'অজানা',
#  9: 'অনেক',
#  10: 'করা',
#  11: 'একটি',
#  12: 'চলছে',
#  13: 'তৃতীয়',
#  14: 'ছিল',
#  15: 'দৌহিত্র',
#  16: 'ভারতের',
#  17: 'শাহইবাঙ্গালাহ',
#  18: 'রাজাগণ',
#  19: 'বঙ্গমগধ',
#  20: 'প্রচণ্ড',
#  21: 'বনলাং',
#  22: 'ঐক্যবদ্ধ',
#  23: 'সম্রাটগণ',
#  24: 'প্রাচীন',
#  25: 'মালব',
#  26: 'রামভদ্রকে',
#  27: 'যখন',
#  28: 'সূত্রেই',
#  29: 'শশাঙ্ক',
#  30: 'পাশের',
#  31: 'মনে',
#  32: 'প্রদেশ',
#  33: 'ওপর',
#  34: 'অভিযাত্রীরা',
#  35: 'হয়',
#  36: 'খ্রিস্টপূর্ব',
#  37: 'মতে',
#  38: 'অভিযোগ',
#  39: 'বাংলায়',
#  40: 'ইরানীয়',
#  41: 'দাক্ষিণাত্য',
#  42: 'নিহত',
#  43: 'গোপালের',
#  44: 'সর্বশ্রেষ্ঠ',
#  45: 'বোঙ্গা',
#  46: 'উপনিবেশ',
#  47: 'অংশ',
#  48: 'হয়েছে',
#  49: 'সম্পূর্ণভাবে',
#  50: 'সমৃদ্ধি',
#  51: 'তুলতেন',
#  52: 'জানা',
#  53: 'বৎসরাজ',
#  54: 'তাকে',
#  55: 'সাম্রাজ্য',
#  56: 'ভারতব্যাপী',
# ...

# %%
#Finding the length of longest word
a = []
b = []
for sentence in sentences:
    b.append(sentence.split())
    a.append(len(sentence.split()))
a
print(b)
maxlen = 6
print(maxlen)
# Out:
# [['বাংলাদেশ', 'দক্ষিণ', 'এশিয়ার', 'একটি', 'জনবহুল', 'ও', 'উন্নয়নশীল', 'রাষ্ট্র'], ['সালের', 'স্বাধীনতা', 'যুদ্ধে', 'পাকিস্তান', 'থেকে', 'স্বাধীনতা', 'অর্জনের', 'পর', 'দেশটি', 'বিশ্ব', 'মানচিত্রে', 'একটি', 'স্বাধীন', 'রাষ্ট্র', 'হিসেবে', 'আবির্ভূত', 'হয়'], ['ভারতীয়', 'উপমহাদেশের', 'পূর্ব', 'অংশে', 'প্রাচীন', 'ও', 'ঐতিহাসিক', 'অঞ্চলের', 'প্রধান', 'অংশের', 'সাথে', 'দেশটির', 'সীমানা', 'মিলেছে', 'যেখানে', 'চার', 'হাজারেরও', 'বেশী', 'বছর', 'ধরে', 'সভ্যতা', 'চলছে', 'ক্যালকোলিথিক', 'যুগেও'], ['এই', 'অঞ্চলের', 'ইতিহাস', 'বাংলার', 'ইতিহাস', 'এবং', 'ভারতের', 'ইতিহাসের', 'সাথে', 'ঘনিষ্ঠভাবে', 'জড়িত'], ['এলাকাটির', 'প্রারম্ভিক', 'ইতিহাস', 'হল', 'ভারতীয়', 'সাম্রাজ্যের', 'উত্তরাধিকার', 'অভ্যন্তরীণ', 'দ্বন্দ্ব', 'এবং', 'হিন্দু', 'ও', 'বৌদ্ধের', 'মধ্যকার', 'দ্বন্দ্বের', 'ইতিহাস'], ['ত্রয়োদশ', 'শতাব্দীর', 'পরে', 'যখন', 'মুসলিম', 'অভিযাত্রীরা', 'যেমন', 'তুর্কী', 'ইরানীয়', 'মুঘল', 'প্রভৃতি', 'এদেশে', 'এসেছিল', 'তখন', 'ইসলাম', 'ধীরে', 'ধীরে', 'প্রভাবশালী', 'হয়ে', 'উঠেছিল'], ['পরবর্তীতে', 'মুসলিম
# ...

# %%
len(sentences)
# Out:
# 129

# %%
#Padding
# for i in range(len(b)):
#  while len(b[i])<maxlen:
#     b[i].append("<word>")

# print(b)
for x in b:
    while len(x)<maxlen:
        x.append("<word>")
print(b)
# Out:
# [['বাংলাদেশ', 'দক্ষিণ', 'এশিয়ার', 'একটি', 'জনবহুল', 'ও', 'উন্নয়নশীল', 'রাষ্ট্র'], ['সালের', 'স্বাধীনতা', 'যুদ্ধে', 'পাকিস্তান', 'থেকে', 'স্বাধীনতা', 'অর্জনের', 'পর', 'দেশটি', 'বিশ্ব', 'মানচিত্রে', 'একটি', 'স্বাধীন', 'রাষ্ট্র', 'হিসেবে', 'আবির্ভূত', 'হয়'], ['ভারতীয়', 'উপমহাদেশের', 'পূর্ব', 'অংশে', 'প্রাচীন', 'ও', 'ঐতিহাসিক', 'অঞ্চলের', 'প্রধান', 'অংশের', 'সাথে', 'দেশটির', 'সীমানা', 'মিলেছে', 'যেখানে', 'চার', 'হাজারেরও', 'বেশী', 'বছর', 'ধরে', 'সভ্যতা', 'চলছে', 'ক্যালকোলিথিক', 'যুগেও'], ['এই', 'অঞ্চলের', 'ইতিহাস', 'বাংলার', 'ইতিহাস', 'এবং', 'ভারতের', 'ইতিহাসের', 'সাথে', 'ঘনিষ্ঠভাবে', 'জড়িত'], ['এলাকাটির', 'প্রারম্ভিক', 'ইতিহাস', 'হল', 'ভারতীয়', 'সাম্রাজ্যের', 'উত্তরাধিকার', 'অভ্যন্তরীণ', 'দ্বন্দ্ব', 'এবং', 'হিন্দু', 'ও', 'বৌদ্ধের', 'মধ্যকার', 'দ্বন্দ্বের', 'ইতিহাস'], ['ত্রয়োদশ', 'শতাব্দীর', 'পরে', 'যখন', 'মুসলিম', 'অভিযাত্রীরা', 'যেমন', 'তুর্কী', 'ইরানীয়', 'মুঘল', 'প্রভৃতি', 'এদেশে', 'এসেছিল', 'তখন', 'ইসলাম', 'ধীরে', 'ধীরে', 'প্রভাবশালী', 'হয়ে', 'উঠেছিল'], ['পরবর্তীতে', 'মুসলিম
# ...

# %%
input_seq = []
target_seq = []

for i,y in enumerate(b):
    print(i)
    # Remove last character for input sequence
    for j in range(len(y)-5):
        input_seq.append(y[j:j+5])
    
    # Remove firsts character for target sequence
        target_seq.append(y[j+1:j+6])
    
    print("Input Sequence: {}\nTarget Sequence: {}".format(input_seq[i], target_seq[i]))
# Out:
# 0
# Input Sequence: ['বাংলাদেশ', 'দক্ষিণ', 'এশিয়ার', 'একটি', 'জনবহুল']
# Target Sequence: ['দক্ষিণ', 'এশিয়ার', 'একটি', 'জনবহুল', 'ও']
# 1
# Input Sequence: ['দক্ষিণ', 'এশিয়ার', 'একটি', 'জনবহুল', 'ও']
# Target Sequence: ['এশিয়ার', 'একটি', 'জনবহুল', 'ও', 'উন্নয়নশীল']
# 2
# Input Sequence: ['এশিয়ার', 'একটি', 'জনবহুল', 'ও', 'উন্নয়নশীল']
# Target Sequence: ['একটি', 'জনবহুল', 'ও', 'উন্নয়নশীল', 'রাষ্ট্র']
# 3
# Input Sequence: ['সালের', 'স্বাধীনতা', 'যুদ্ধে', 'পাকিস্তান', 'থেকে']
# Target Sequence: ['স্বাধীনতা', 'যুদ্ধে', 'পাকিস্তান', 'থেকে', 'স্বাধীনতা']
# 4
# Input Sequence: ['স্বাধীনতা', 'যুদ্ধে', 'পাকিস্তান', 'থেকে', 'স্বাধীনতা']
# Target Sequence: ['যুদ্ধে', 'পাকিস্তান', 'থেকে', 'স্বাধীনতা', 'অর্জনের']
# 5
# Input Sequence: ['যুদ্ধে', 'পাকিস্তান', 'থেকে', 'স্বাধীনতা', 'অর্জনের']
# Target Sequence: ['পাকিস্তান', 'থেকে', 'স্বাধীনতা', 'অর্জনের', 'পর']
# 6
# Input Sequence: ['পাকিস্তান', 'থেকে', 'স্বাধীনতা', 'অর্জনের', 'পর']
# ...

# %%
for i in range(len(input_seq)):
    input_seq[i] = [word2int[w] for w in input_seq[i]]
    target_seq[i] = [word2int[w] for w in target_seq[i]]

# %%
import numpy as np

# %%
dict_size = len(word2int)
seq_len = maxlen - 1
batch_size = len(input_seq)
print("dict_size: ", dict_size)
print("seq_len: ", seq_len)
print("batch_size: ", batch_size)

def one_hot_encode(sequence, dict_size, seq_len, batch_size):
    # Creating a multi-dimensional array of zeros with the desired output shape
    features = np.zeros((batch_size, seq_len, dict_size), dtype=np.float32)
    
    # Replacing the 0 at the relevant character index with a 1 to represent that character
    
    for i in range(batch_size):
        for u in range(seq_len):
            features[i, u, sequence[i][u]] = 1
            
    return features
# Out:
# dict_size:  733
# seq_len:  5
# batch_size:  911

# %%
input_seq = one_hot_encode(input_seq, dict_size, seq_len, batch_size)
print("Input shape: {} --> (Batch Size, Sequence Length, One-Hot Encoding Size)".format(input_seq.shape))
# Out:
# Input shape: (911, 5, 733) --> (Batch Size, Sequence Length, One-Hot Encoding Size)

# %%
import torch
from torch import nn

# %%
device = torch.device("cpu")

# %%
input_seq = torch.Tensor(input_seq)
target_seq = torch.Tensor(target_seq)

# %%
class Model(nn.Module):
    def __init__(self, input_size, output_size, hidden_dim, n_layers):
        super(Model, self).__init__()

        # Defining some parameters
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        #Defining the layers
        # RNN Layer
        self.rnn = nn.RNN(input_size, hidden_dim, n_layers, batch_first=True)   
        # Fully connected layer
        self.fc = nn.Linear(hidden_dim, output_size)
    
    def forward(self, x):
        
        batch_size = x.size(0)
#         print("batch_size", batch_size)

        #Initializing hidden state for first input using method defined below
        hidden = self.init_hidden(batch_size)
#         print("hidden", hidden.shape)
        

        # Passing in the input and hidden state into the model and obtaining outputs
        out, hidden = self.rnn(x, hidden)
        
        # Reshaping the outputs such that it can be fit into the fully connected layer
        out = out.contiguous().view(-1, self.hidden_dim)
        out = self.fc(out)
        
        return out, hidden
    
    def init_hidden(self, batch_size):
        # This method generates the first hidden state of zeros which we'll use in the forward pass
        hidden = torch.zeros(self.n_layers, batch_size, self.hidden_dim).to(device)
         # We'll send the tensor holding the hidden state to the device we specified earlier as well
        return hidden

# %%
# Instantiate the model with hyperparameters
model = Model(input_size=len(word2int), output_size=len(word2int), hidden_dim=180, n_layers=1)
# We'll also set the model to the device that we defined earlier (default is CPU)
model.to(device)

# Define hyperparameters
n_epochs = 150
lr=0.01

# Define Loss, Optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
# Training Run
for epoch in range(1, n_epochs + 1):
    optimizer.zero_grad() # Clears existing gradients from previous epoch
    input_seq = input_seq.to(device)
#     print(input_seq.shape)
    output, hidden = model(input_seq)
    loss = criterion(output, target_seq.view(-1).long())
    loss.backward() # Does backpropagation and calculates gradients
    optimizer.step() # Updates the weights accordingly
    
    if epoch%10 == 0:
        print('Epoch: {}/{}.............'.format(epoch, n_epochs), end=' ')
        print("Loss: {:.4f}".format(loss.item()))
# Out:
# Epoch: 10/150............. Loss: 4.9925
# Epoch: 20/150............. Loss: 1.4585
# Epoch: 30/150............. Loss: 0.3855
# Epoch: 40/150............. Loss: 0.2321
# Epoch: 50/150............. Loss: 0.2021
# Epoch: 60/150............. Loss: 0.1930
# Epoch: 70/150............. Loss: 0.1896
# Epoch: 80/150............. Loss: 0.1881
# Epoch: 90/150............. Loss: 0.1873
# Epoch: 100/150............. Loss: 0.1868
# Epoch: 110/150............. Loss: 0.1864
# Epoch: 120/150............. Loss: 0.1861
# Epoch: 130/150............. Loss: 0.1859
# Epoch: 140/150............. Loss: 0.1857
# Epoch: 150/150............. Loss: 0.1855

# %%
def predict(model, word):
    # One-hot encoding our input to fit into the model
    word = np.array([[word2int[w] for w in word]])
    word = one_hot_encode(word, dict_size, word.shape[1], 1)
    word = torch.from_numpy(word)
    word.to(device)
    
    out, hidden = model(word)

    prob = nn.functional.softmax(out[-1], dim=0).data
    # Taking the class with the highest probability score from the output
    word_ind = torch.max(prob, dim=0)[1].item()

    return int2word[word_ind], hidden

# %%
def sample(model, out_len, start='দক্ষিণ'):
    model.eval() # eval mode
    words = start.split()
    # First off, run through the starting characters
    size = out_len - len(words)
    # Now pass in the previous characters and get a new one
    for ii in range(size):
        word, h = predict(model, words)
        words.append(word)

    return ' '.join(words)

# %%
input_txt = "শ্রীলঙ্কায় রাজারা ক্ষমতা"
output = sample(model, 7, input_txt)

# %%
with open('Predicted_Bangla_Words.txt','a+',encoding='utf-8') as f:
    input_data = "\n\nInput Data: " + input_txt +"\n"
    line = "Output Data: " + output
    f.write(input_data)
    f.write(line)
